# %% [markdown]
# Project Description: There are 4 source systems in this project from where we need to load data in python data frames
#
# All these source systems are some third party databases, and have similar schema. For one of the source that is CSV_s1, we also got source schema extract to understand the fields defintion.
#
# Note- Same schema is applicable for all 4 source systems datasets. Each data source system contains 3 types of datasets named Customers, Products, and Transactions.
#
# Made by ABHISHEK SATAV

# %%
from google.colab import files

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-1127c3d9-7920-436c-97b6-96de1f75b5c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1127c3d9-7920-436c-97b6-96de1f75b5c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df_customers = pd.read_csv('customers.csv')
df_customers.head()
# Out:
#    'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  'contactNo'  \
# 0         1      Leslie       Bass        F     27            B        37307
# 1         2        Judy      Burks        M     53            S        84759
# 2         3      Marsha      Doyle        F     48            B        80932
# 3         4      Alexis     Battle        M     27            S        71701
# 4         5      Martha      Combs        F     49            B        83947
#
#                 'emailId'   'city'    'state' 'isActive'        'createdDate'  \
# 0  endslost@everyma1l.org   Gibson   Dellwood          Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue          Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla          Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis          Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood          Y  2017-05-15 07:34:35
#
#          'UpdatedDate'
# ...

# %%
df_products = pd.read_csv('products.csv')
df_products.head()
# Out:
#    'productno' 'productName' 'Description' 'isActive'        'createdDate'  \
# 0            1      Product1    pgqorighfa          Y  2017-04-03 07:58:55
# 1            2      Product2    lmndaaweth          Y  2017-09-21 12:38:31
# 2            3      Product3    urifeubrhh          Y  2017-09-08 10:32:12
# 3            4      Product4    rlpcjxfarp          Y  2017-05-22 05:29:27
# 4            5      Product5    hzcpozsgfc          Y  2017-02-02 08:40:29
#
#          'UpdatedDate'
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
transactions_list = ['txnno','txndate','custno','amount','productno','spendby']
df_transactions = pd.read_csv('transactions.csv',names=transactions_list)
df_transactions.head()
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %% [markdown]
# Usecase-2 Display only those customers from CSV_s1, who purchased more than 3 products

# %%
df_1 = pd.merge(df_customers,df_transactions,left_on="'custno'" , right_on='custno')
df_1.head(2)
# Out:
#    'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  'contactNo'  \
# 0         2        Judy      Burks        M     53            S        84759
# 1         2        Judy      Burks        M     53            S        84759
#
#                 'emailId'   'city' 'state' 'isActive'        'createdDate'  \
# 0  rfleming@hotma1l.co.uk  Suwanee  Trabue          Y  2017-05-22 05:29:22
# 1  rfleming@hotma1l.co.uk  Suwanee  Trabue          Y  2017-05-22 05:29:22
#
#          'UpdatedDate'  txnno              txndate  custno  amount  productno  \
# 0  2017-10-18 12:12:28    423  2017-10-18 12:31:46       2    4245        136
# 1  2017-10-18 12:12:28    973  2017-10-18 12:31:46       2    4717        842
#
#   spendby
# 0    Cash
# 1    Card

# %%
df_2 = df_1.groupby('custno').count()
df_2.head(10)
# Out:
#         'custno'  'firstname'  'lastname'  'gender'  'age'  'profession'  \
# custno
# 2              2            2           2         2      2             2
# 3              1            1           1         1      1             1
# 4              4            4           4         4      4             4
# 5              1            1           1         1      1             1
# 7              1            1           1         1      1             1
# 8              2            2           2         2      2             2
# 9              1            1           1         1      1             1
# 10             1            1           1         1      1             1
# 12             2            2           2         2      2             2
# 16             2            2           2         2      2             2
#
#         'contactNo'  'emailId'  'city'  'state'  'isActive'  'createdDate'  \
# custno
# ...

# %%
df_2[df_2["'custno'"] > 3]
# Out:
#         'custno'  'firstname'  'lastname'  'gender'  'age'  'profession'  \
# custno
# 4              4            4           4         4      4             4
# 86             4            4           4         4      4             4
# 167            4            4           4         4      4             4
# 187            4            4           4         4      4             4
# 237            4            4           4         4      4             4
# 241            5            5           5         5      5             5
# 321            4            4           4         4      4             4
# 326            4            4           4         4      4             4
# 331            4            4           4         4      4             4
# 356            4            4           4         4      4             4
# 391            5            5           5         5      5             5
# 537            4            4           4         4      4             4
# ...

# %%
dataf = df_2 [ df_2['txnno'] > 3]
finaldata = pd.DataFrame(dataf)
finaldata
# Out:
#         'custno'  'firstname'  'lastname'  'gender'  'age'  'profession'  \
# custno
# 4              4            4           4         4      4             4
# 86             4            4           4         4      4             4
# 167            4            4           4         4      4             4
# 187            4            4           4         4      4             4
# 237            4            4           4         4      4             4
# 241            5            5           5         5      5             5
# 321            4            4           4         4      4             4
# 326            4            4           4         4      4             4
# 331            4            4           4         4      4             4
# 356            4            4           4         4      4             4
# 391            5            5           5         5      5             5
# 537            4            4           4         4      4             4
# ...

# %%
df_1 = pd.merge(df_customers,df_transactions,left_on="'custno'" , right_on='custno' ) # merge customer and transaction df
df_2 = df_1.groupby('custno').count() # group all records related to same custno in same group and check count
df_3 = df_customers.set_index("'custno'") # set custno as index
df_3['Product_purchased'] = df_2['txnno'] # add purchase count (count of transactions ) column in customer df
df_3[df_3['Product_purchased']>3] # filter out records based on count
# Out:
#          'firstname' 'lastname' 'gender'  'age' 'profession'  'contactNo'  \
# 'custno'
# 4             Alexis     Battle        M     27            S        71701
# 86            Bonnie     McCall        M     37            S        70907
# 167            Alice      Blake        F     58            B        22324
# 187             Alan    Anthony        F     50            B        40487
# 237             Dawn       West        F     26            B        75618
# 241          Derrick    Pearson        F     33            B        74138
# 321          Crystal         Le        F     64            B        37857
# 326            Heidi    Stanley        M     29            S        78822
# 331          Cynthia   Harrison        F     49            B        53439
# 356         Mitchell      Mason        M     37            S        45064
# 391            Keith     Church        F     19            B        26859
# ...

# %%
df_1.corr()
# Out:
# <ipython-input-17-e6c3a4301a77>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_1.corr()
#              'custno'     'age'  'contactNo'     txnno    custno    amount  \
# 'custno'     1.000000  0.008032     0.024747 -0.037690  1.000000 -0.022528
# 'age'        0.008032  1.000000    -0.085475  0.055327  0.008032  0.014348
# 'contactNo'  0.024747 -0.085475     1.000000 -0.040443  0.024747 -0.047076
# txnno       -0.037690  0.055327    -0.040443  1.000000 -0.037690  0.045967
# custno       1.000000  0.008032     0.024747 -0.037690  1.000000 -0.022528
# amount      -0.022528  0.014348    -0.047076  0.045967 -0.022528  1.000000
# productno   -0.069176  0.001470     0.020377  0.023228 -0.069176 -0.018086
#
#              productno
# 'custno'     -0.069176
# 'age'         0.001470
# 'contactNo'   0.020377
# ...

# %% [markdown]
# ## Usecase-3 Display top 5 most demanded products from CSV_

# %%
df_4 = pd.merge(df_products,df_transactions,left_on="'productno'",right_on='productno')
df_5 = df_4.groupby('productno').count()
df_6 = df_products.set_index("'productno'")
df_6['Product_Sold'] = df_5['custno']
df_6.sort_values(by='Product_Sold',ascending=False).head()
# Out:
#             'productName' 'Description' 'isActive'        'createdDate'  \
# 'productno'
# 82              Product82    ignxxzodmc          Y  2017-09-24 02:57:26
# 768            Product768    hvfbltpjun          Y  2017-01-27 11:45:21
# 900            Product900    ouoolyahlh          N  2017-01-10 12:35:30
# 427            Product427    rnqzbzweys          Y  2017-09-14 10:44:57
# 233            Product233    yrblgllvfy          Y  2017-05-31 10:50:17
#
#                    'UpdatedDate'  Product_Sold
# 'productno'
# 82           2017-10-18 12:12:38           5.0
# 768          2017-10-18 12:12:39           5.0
# 900          2017-10-18 12:12:39           5.0
# 427          2017-10-18 12:12:38           5.0
# 233          2017-10-18 12:12:38           4.0

# %% [markdown]
# Usecase-4 Display top 5 transactions amount from CSV_s1

# %%
df_7 = df_transactions.sort_values('amount',ascending=False)
df_7['amount'].head()
# Out:
# 556    4996
# 305    4992
# 574    4981
# 531    4980
# 232    4966
# Name: amount, dtype: int64

# %% [markdown]
# Usecase-5 Display distinct professions from CSV_s1

# %%
df_customers["'profession'"].unique()
# Out:
# array(['B', 'S'], dtype=object)

# %%
df_customers["'profession'"].value_counts()
# Out:
# B    500
# S    500
# Name: 'profession', dtype: int64

# %% [markdown]
# Usecase-6 Display highest age in CSV_s1 customer’s dataset

# %%
df_customers["'age'"].max()
# Out:
# 64

# %% [markdown]
# Usecase-7 Display custno, gender, age, profession, contactno, productno, productName, txndate, spendby, amount from CSV_s1 for custno = 923

# %%
df_8 = pd.merge(df_products[["'productno'","'productName'"]],df_transactions,left_on="'productno'",right_on='productno')
df_9 = pd.merge(df_customers,df_8,left_on="'custno'" , right_on='custno')
df_10 = df_9[df_9['custno'] == 923]
df_10[['custno', "'gender'", "'age'", "'profession'", "'contactNo'", 'productno', "'productName'",'txndate', 'spendby', 'amount']]
# Out:
#      custno 'gender'  'age' 'profession'  'contactNo'  productno  \
# 929     923        F     46            B        25436        113
# 930     923        F     46            B        25436        376
# 931     923        F     46            B        25436        644
#
#     'productName'              txndate spendby  amount
# 929    Product113  2017-10-18 12:31:46    Card    2303
# 930    Product376  2017-10-18 12:31:45    Card    2559
# 931    Product644  2017-10-18 12:31:46    Cash    4553

# %% [markdown]
# **Usecase-8 Load all three PSV (pipe separated values) dataset in Pandas Data frames and display first 5 records**

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-96c6e960-4f74-42a0-afee-1c2a22e6bcd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96c6e960-4f74-42a0-afee-1c2a22e6bcd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
columns = ['custno','firstname','lastname','gender','age','profession','contactNo',       #adding headers
'emailId','city','state','isActive','createdDate','UpdatedDate']

customer = pd.read_csv('customers.txt', names = columns, delimiter ='|')

# %%
pd.DataFrame(customer.head())
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       1    Leslie     Bass      F   27          B      37307
# 1       2      Judy    Burks      M   53          S      84759
# 2       3    Marsha    Doyle      F   48          B      80932
# 3       4    Alexis   Battle      M   27          S      71701
# 4       5    Martha    Combs      F   49          B      83947
#
#                   emailId     city      state isActive          createdDate  \
# 0  endslost@everyma1l.org   Gibson   Dellwood        Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue        Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla        Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis        Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood        Y  2017-05-15 07:34:35
#
#            UpdatedDate
# 0  2017-10-18 12:12:28
# 1  2017-10-18 12:12:28
# 2  2017-10-18 12:12:28
# 3  2017-10-18 12:12:28
# ...

# %%
columns = ['productno','productName','Description','isActive','createdDate','UpdatedDate']

product = pd.read_csv('products.txt', names = columns, delimiter = '|')

# %%
pd.DataFrame(product.head())
# Out:
#    productno productName Description isActive          createdDate  \
# 0          1    Product1  pgqorighfa        Y  2017-04-03 07:58:55
# 1          2    Product2  lmndaaweth        Y  2017-09-21 12:38:31
# 2          3    Product3  urifeubrhh        Y  2017-09-08 10:32:12
# 3          4    Product4  rlpcjxfarp        Y  2017-05-22 05:29:27
# 4          5    Product5  hzcpozsgfc        Y  2017-02-02 08:40:29
#
#            UpdatedDate
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %%
columns = ['txnno','txndate','custno','amount','productno','spendby']

transaction = pd.read_csv('transactions.txt', names = columns, delimiter = '|')

# %%
pd.DataFrame(transaction.head())
# Out:
#    txnno              txndate  custno  amount  productno spendby
# 0      1  2017-10-18 12:31:45     923    2559        376    Card
# 1      2  2017-10-18 12:31:45     219    1706        151    Card
# 2      3  2017-10-18 12:31:45     927    3462        707    Cash
# 3      4  2017-10-18 12:31:45     806     865        539    Card
# 4      5  2017-10-18 12:31:45     958    2494         25    Card

# %% [markdown]
# **Usecase-9 Load all three JSON datasets in Pandas Data frames and display first 5 records.**

# %%
import pandas as pd
import json
from google.colab import files

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-53aff3d4-ba95-4ce5-beac-11a744b85686" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53aff3d4-ba95-4ce5-beac-11a744b85686">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
customer = pd.read_json('customers.json', lines = True)
pd.DataFrame(customer.head())
# Out:
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# 0  2017-03-01  2018-08-25
# ...

# %%
product = pd.read_json('products.json', lines = True)
pd.DataFrame(product.head())
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
trans = pd.read_json('transactions.json', lines = True)
pd.DataFrame(trans.head(5))
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2

# %% [markdown]
# **Usecase-10 Load all three XML datasets in Pandas Data frames and display first 5 records.**

# %%
data = files.upload()
# Out:
#      <input type="file" id="files-09bd09ed-1fd0-4e9b-9140-e8bcfd95354c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09bd09ed-1fd0-4e9b-9140-e8bcfd95354c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pandas.io.xml import read_xml
customer = pd.read_xml('customers.xml')
pd.DataFrame(customer.head())
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# ...

# %%
from pandas.io.xml import read_xml
product = pd.read_xml('products.xml')
pd.DataFrame(product.head())
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100  Hyundai Motors       eight         2  2017-10-01  2017-11-04
# 1        101           Honda       eight         1  2017-04-10  2017-11-11
# 2        102             GMC       three         2  2017-02-09  2017-11-17
# 3        103           Lexus       eight         2  2017-06-01  2017-11-04
# 4        104           Smart        five         2  2017-08-10  2017-11-16

# %%
from pandas.io.xml import read_xml
trans = pd.read_xml('transactions.xml')
pd.DataFrame(trans.head())
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-09-16       6     576         73        1
# 1      2  2018-02-11      96    1038         40        2
# 2      3  2017-06-13      17     673          2        1
# 3      4  2017-07-25      89    1284        100        2
# 4      5  2017-06-15       9    1685         56        2
